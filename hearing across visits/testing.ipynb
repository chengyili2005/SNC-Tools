# %% [markdown]
# # How to use the data structure created in MATLAB imported into Python

# %%
# Load the matlab file using SciPy
import scipy.io
mat = scipy.io.loadmat('Data_All_Jul25.mat') # Ensure correct file path

# %%
# This took my computer 7.5 minutes to load...
# Note: If you want a visualization of what this struct looks like, I'd recommend saving the output of this cell as a .json file and viewing it there.
mat

# %%
data = mat['ans']

# %%
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %%
import numpy as np

# %%
data.shape # This is a 1 by 190 object. It can be best viewed through matlab, but essentially:

# id, attn_beh, aud, cog, eeg, subj_info
# 1003
# 1004
# 1005 (and so on until 190...)
# Out:
# (1, 190)

# %%
# Let's try iterating through all participants. 
# Since the dimensions are 1x190, we'll have to grab the 0th index of the first dimension.
# Then, each index of the next dimension represents a participant.

# For example, this is the first participant
data[0][0] 

# This is the last participant
data[0][189]
# Out:
# np.void((array([[3124]], dtype=uint16), array([[(array([[3124]], dtype=uint16), array([[1]], dtype=uint8), MatlabOpaque([(b'', b'MCOS', b'datetime', array([[3707764736],
#                              [         2],
#                              [         1],
#                              [         1],
#                              [    119615],
#                              [         1]], dtype=uint32))            ],
#                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[(array([[3124]], dtype=uint16), MatlabOpaque([(b'', b'MCOS', b'datetime', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    119616],
#                                      [         1]], dtype=uint32))            ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[5]], dtype=uint8), array(['LilyL_FourB_T2_JN_M'], dtype='<U19'), array([[(MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119617],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119618],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[2]], dtype=uint8), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119619],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[2]], dtype=uint8), array([[1]], dtype=uint8), array([[19.01977587]]))          ,
#                         (MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119620],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119621],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[4]], dtype=uint8), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119622],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[4]], dtype=uint8), array([[1]], dtype=uint8), array([[5.64654803]]))           ,
#                         (MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119623],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119624],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[4]], dtype=uint8), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119625],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[4]], dtype=uint8), array([[1]], dtype=uint8), array([[6.59176707]]))           ,
#                         (MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119626],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119627],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[4]], dtype=uint8), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119628],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[4]], dtype=uint8), array([[1]], dtype=uint8), array([[4.49676299]]))           ,
#                         (MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119629],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119630],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[1]], dtype=uint8), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119631],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[1]], dtype=uint8), array([[1]], dtype=uint8), array([[4.27044201]]))           ]],
#                       dtype=[('question_text', 'O'), ('answer_text', 'O'), ('answer_num', 'O'), ('resp_text', 'O'), ('resp_num', 'O'), ('answer_corr', 'O'), ('rt', 'O')]), array([[(array([[ 12.0681574 ],
#                                [ 19.65296132],
#                                [ 30.01421705],
#                                [ 45.68020223],
#                                [ 55.18566483],
#                                [ 65.25868228],
#                                [ 80.34108094],
#                                [ 97.22289517],
#                                [101.17524116],
#                                [122.25022411],
#                                [143.70869616],
#                                [145.78882316],
#                                [160.50290742],
#                                [175.45689142],
#                                [194.16341702],
#                                [205.50867584],
#                                [212.20557511],
#                                [215.14978611],
#                                [239.56103652],
#                                [271.55706699],
#                                [296.00820866],
#                                [313.43447991],
#                                [327.78022781],
#                                [340.99797044],
#                                [351.0633202 ]]), array([[(array([[11.13]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119632],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))     ,
#                                 (array([[19.07]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119633],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))     ,
#                                 (array([[29.259999]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119634],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))         ,
#                                 (array([[45.02]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119635],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))     ,
#                                 (array([[54.06]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119636],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))     ,
#                                 (array([[64.48]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119637],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))     ,
#                                 (array([[79.66]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119638],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))     ,
#                                 (array([[86.69]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119639],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))     ,
#                                 (array([[96.58]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119640],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))     ,
#                                 (array([[100.66]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119641],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[121.4]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119642],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))     ,
#                                 (array([[142.4]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119643],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))     ,
#                                 (array([[144.73]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119644],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[159.81]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119645],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[174.86]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119646],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[192.28]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119647],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[204.75]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119648],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[211.059999]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119649],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))          ,
#                                 (array([[238.73]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119650],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[270.79]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119651],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[295.3]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119652],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))     ,
#                                 (array([[312.73]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119653],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[326.69]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119654],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[340.17]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119655],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[350.32]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119656],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ]],
#                               dtype=[('word_onset', 'O'), ('desc', 'O')]), array([[(array([[7.57]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119657],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))    ,
#                                 (array([[16.26]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119658],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))     ,
#                                 (array([[24.56]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119659],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))     ,
#                                 (array([[53.98]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119660],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))     ,
#                                 (array([[73.09]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119661],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))     ,
#                                 (array([[90.65]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119662],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))     ,
#                                 (array([[116.61]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119663],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[128.52]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119664],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[150.93]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119665],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[173.02]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119666],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[197.26]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119667],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[214.279999]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119668],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))          ,
#                                 (array([[224.79]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119669],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[239.37]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119670],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[249.33]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119671],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[261.08]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119672],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[269.809999]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119673],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))          ,
#                                 (array([[281.54]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119674],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[291.03]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119675],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[300.65]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119676],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[315.559999]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119677],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))          ,
#                                 (array([[343.07]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119678],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[373.96]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119679],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ,
#                                 (array([[381.5]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119680],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))     ,
#                                 (array([[386.22]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                                      [         2],
#                                                      [         1],
#                                                      [         1],
#                                                      [    119681],
#                                                      [         2]], dtype=uint32))          ],
#                                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))      ]],
#                               dtype=[('word_onset', 'O'), ('desc', 'O')]))                                                                                       ]],
#                       dtype=[('key_press_lat', 'O'), ('targ_cwords', 'O'), ('dist_cwords', 'O')]), array([[(MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119682],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[42.83854167]]), array([[2.71832204]])),
#                         (MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119683],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[43.81510417]]), array([[2.93523216]])),
#                         (MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119684],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[27.86458333]]), array([[2.80176616]])),
#                         (MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119685],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[36.97916667]]), array([[2.08449101]])),
#                         (MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119686],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[66.6015625]]), array([[2.36795592]])),
#                         (MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119687],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[31.4453125]]), array([[2.20096111]]))]],
#                       dtype=[('question_text', 'O'), ('resp', 'O'), ('rt', 'O')]), array([[0.22834396, 0.32278204, 0.26794338, 0.22509933, 0.24024439]]))                                                                                ]],
#               dtype=[('id', 'O'), ('end_time', 'O'), ('block', 'O'), ('story_cond', 'O'), ('compq', 'O'), ('cword', 'O'), ('fatigue', 'O'), ('flash', 'O')]), array([[(array([[3124]], dtype=uint16), MatlabOpaque([(b'', b'MCOS', b'datetime', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    119688],
#                                      [         1]], dtype=uint32))            ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[6]], dtype=uint8), array(['Maste_silence_T1_JN_M'], dtype='<U21'), array([[(MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119689],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119690],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[1]], dtype=uint8), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119691],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[1]], dtype=uint8), array([[1]], dtype=uint8), array([[6.70000911]]))           ,
#                         (MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119692],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119693],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[3]], dtype=uint8), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119694],
#                                              [         2]], dtype=uint32))          ],
#                                      dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[3]], dtype=uint8), array([[1]], dtype=uint8), array([[4.10660601]]))           ,
#                         (MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                              [         2],
#                                              [         1],
#                                              [         1],
#                                              [    119695],
#                                              [         2]], dtype=uint32))          ],
# ...
#                       dtype=[('id', 'O'), ('targ', 'O'), ('dist', 'O')]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120235],
#                                      [         2]], dtype=uint32))          ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120236],
#                                      [         2]], dtype=uint32))          ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ]],
#               dtype=[('id', 'O'), ('story_cond', 'O'), ('erp', 'O'), ('tf', 'O'), ('eye', 'O')]))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ]],
#       dtype=[('id', 'O'), ('Maste_silence_T1_JN_M', 'O'), ('Fishe_silence_T1_JY_M', 'O'), ('FourB_LilyL_T2_JN_F', 'O'), ('LilyL_FourB_T2_JN_M', 'O'), ('White_Perse_T2_JY_F', 'O'), ('Perse_White_T2_JY_M', 'O')]), array([[(array([[3124]], dtype=uint16), array([[(array([[3124]], dtype=uint16), MatlabOpaque([(b'', b'MCOS', b'datetime', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120237],
#                                      [         1]], dtype=uint32))            ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), MatlabOpaque([(b'', b'MCOS', b'datetime', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120238],
#                                      [         1]], dtype=uint32))            ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[nan]]), array([[nan]]), array([[nan]]), MatlabOpaque([(b'', b'MCOS', b'datetime', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120239],
#                                      [         1]], dtype=uint32))            ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120240],
#                                      [         2]], dtype=uint32))          ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[nan]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120241],
#                                      [         2]], dtype=uint32))          ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[nan]]), array([[nan]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120242],
#                                      [         2]], dtype=uint32))          ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120243],
#                                      [         2]], dtype=uint32))          ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[nan]]), array([[nan]]), array([[nan]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120244],
#                                      [         2]], dtype=uint32))          ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120245],
#                                      [         2]], dtype=uint32))          ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[nan]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120246],
#                                      [         2]], dtype=uint32))          ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[nan]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120247],
#                                      [         2]], dtype=uint32))          ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[nan]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120248],
#                                      [         2]], dtype=uint32))          ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[nan]]), array([[nan]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120249],
#                                      [         2]], dtype=uint32))          ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[nan]]), array([[nan]]), array([[nan]]), array([[nan]]), array([[nan]]), array([[nan]]), array([[nan]]))]],
#               dtype=[('id', 'O'), ('start_date', 'O'), ('end_date', 'O'), ('progress', 'O'), ('duration', 'O'), ('finished', 'O'), ('recorded_date', 'O'), ('user_lang', 'O'), ('age', 'O'), ('veteran_status', 'O'), ('sex', 'O'), ('eng_fluency', 'O'), ('first_lang', 'O'), ('other_langs', 'O'), ('yrs_edu', 'O'), ('yrs_music_training', 'O'), ('age_begin_music', 'O'), ('handedness', 'O'), ('vision', 'O'), ('is_color_blind', 'O'), ('hearing_ability', 'O'), ('hearing_diagnosed', 'O'), ('cause_hearloss', 'O'), ('has_tinnitus', 'O'), ('tinnitus_ears', 'O'), ('brain_cond_speech', 'O'), ('brain_cond_any', 'O'), ('brain_cond_desc', 'O'), ('has_scalp_probs', 'O'), ('ladder', 'O'), ('agree_race_ethnic', 'O'), ('ethnic_origin', 'O'), ('racial_origin', 'O'), ('has_ssn', 'O'), ('couse_credit', 'O')]), array([[(array([[3124]], dtype=uint16), MatlabOpaque([(b'', b'MCOS', b'datetime', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120250],
#                                      [         1]], dtype=uint32))            ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), MatlabOpaque([(b'', b'MCOS', b'datetime', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120251],
#                                      [         1]], dtype=uint32))            ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[nan]]), array([[nan]]), array([[nan]]), MatlabOpaque([(b'', b'MCOS', b'datetime', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120252],
#                                      [         1]], dtype=uint32))            ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120253],
#                                      [         2]], dtype=uint32))          ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), MatlabOpaque([(b'', b'MCOS', b'datetime', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120254],
#                                      [         1]], dtype=uint32))            ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[nan]]), MatlabOpaque([(b'', b'MCOS', b'string', array([[3707764736],
#                                      [         2],
#                                      [         1],
#                                      [         1],
#                                      [    120255],
#                                      [         2]], dtype=uint32))          ],
#                              dtype=[('s0', 'O'), ('s1', 'O'), ('s2', 'O'), ('arr', 'O')]), array([[nan]]), array([[nan]]), array([[nan]]), array([[nan]]), array([[nan]]), array([[nan]]), array([[(array([[nan]]), array([[nan]]))]],
#                       dtype=[('score', 'O'), ('exp', 'O')]), array([[(array([[nan]]), array([[nan]]))]],
#                       dtype=[('score', 'O'), ('exp', 'O')]), array([[(array([[nan]]), array([[nan]]))]],
#                       dtype=[('score', 'O'), ('exp', 'O')]), array([[(array([[nan]]), array([[nan]]))]],
#                       dtype=[('score', 'O'), ('exp', 'O')]), array([[(array([[nan]]), array([[nan]]))]],
#                       dtype=[('score', 'O'), ('exp', 'O')]), array([[(array([[nan]]), array([[nan]]))]],
#                       dtype=[('score', 'O'), ('exp', 'O')]), array([[(array([[nan]]), array([[nan]]))]],
#                       dtype=[('score', 'O'), ('exp', 'O')]), array([[(array([[nan]]), array([[nan]]))]],
#                       dtype=[('score', 'O'), ('exp', 'O')]), array([[(array([[nan]]), array([[nan]]))]],
#                       dtype=[('score', 'O'), ('exp', 'O')]), array([[(array([[nan]]), array([[nan]]))]],
#                       dtype=[('score', 'O'), ('exp', 'O')]), array([[(array([[nan]]), array([[nan]]))]],
#                       dtype=[('score', 'O'), ('exp', 'O')]), array([[(array([[nan]]), array([[nan]]))]],
#                       dtype=[('score', 'O'), ('exp', 'O')]), array([[nan]]))                                                                                                                                                          ]],
#               dtype=[('id', 'O'), ('start_date', 'O'), ('end_date', 'O'), ('progress', 'O'), ('duration', 'O'), ('finished', 'O'), ('recorded_date', 'O'), ('user_lang', 'O'), ('date', 'O'), ('age', 'O'), ('hearingAids', 'O'), ('y_l_ha', 'O'), ('m_l_ha', 'O'), ('w_l_ha', 'O'), ('y_r_ha', 'O'), ('m_r_ha', 'O'), ('w_r_ha', 'O'), ('q1', 'O'), ('q2', 'O'), ('q3', 'O'), ('q4', 'O'), ('q5', 'O'), ('q6', 'O'), ('q7', 'O'), ('q8', 'O'), ('q9', 'O'), ('q10', 'O'), ('q11', 'O'), ('q12', 'O'), ('score', 'O')]), array([[(array([[3124]], dtype=uint16), array([[nan]]), array([[nan]]), array([[nan]]), array([[nan]]), array([[nan]]))]],
#               dtype=[('id', 'O'), ('vet_status', 'O'), ('mil_iscore', 'O'), ('non_mil_occ_iscore', 'O'), ('non_occ_iscore', 'O'), ('total_iscore', 'O')]))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ]],
#       dtype=[('id', 'O'), ('demo', 'O'), ('ssq', 'O'), ('lensq', 'O')])), dtype=[('id', 'O'), ('attn_beh', 'O'), ('aud', 'O'), ('cog', 'O'), ('eeg', 'O'), ('subj_info', 'O')])

# %%
# How many participants do we have?
print(len(data[0]))
# Out:
# 190

# %%
# Here's how to get the ID of the last participant
data[0][189][0][0][0]
# Out:
# np.uint16(3124)

# %%
# Let's focus on the first participant.
# The index mapping can get a little confusing.
# This is to get the first participant's audiogram, AirCon, right ear, 500hz score.
data[0][0]['aud']['audiogram'][0][0]['ac'][0][0]['right'][0][0]['f500'][0][0][0][0]
# Out:
# np.uint8(5)

# %% [markdown]
# # Check differences between two xlsx files

# %%
import pandas as pd
original = pd.read_excel('../output_excel.xlsx')
new = pd.read_excel('../output_excel1.xlsx')

# %%
print(f"Original length: {len(original)}\nNew Length: {len(new)}")
# Out:
# Original length: 203
# New Length: 203

# %%
print(1003 in original['ID'].values)
# Out:
# True

# %%
not_in_new = []
not_in_original = []
for id in original['ID'].values:
	if id not in new['ID'].values:
		not_in_new.append(id)
for id in new['ID'].values:
	if id not in original['ID'].values:
		not_in_original.append(id)
difference = not_in_new + not_in_original

# %%
print(f"Original length: {len(original)}\nNew Length: {len(new)}\nNot In New Length: {len(not_in_new)}\nNot In Original Length: {len(not_in_original)}")
# Out:
# Original length: 203
# New Length: 203
# Not In New Length: 0
# Not In Original Length: 0

# %%
difference
# Out:
# []

# %%
ids = []
clin_prof = []
military_prof = []
for row in new.iterrows():
	if (row[1]['ID'] not in difference):
		ids.append(row[1]['ID'])
		clin_prof.append(row[1]['Clinical Profile'])
		military_prof.append(row[1]['Military Profile'])
new_cleaned = pd.DataFrame({
	"ID" : ids,
	"Clinical Profile" : clin_prof,
	"Military Profile" : military_prof
})

# %%
ids = []
clin_prof = []
military_prof = []
for row in original.iterrows():
	if (row[1]['ID'] not in difference):
		ids.append(row[1]['ID'])
		clin_prof.append(row[1]['Clinical Profile'])
		military_prof.append(row[1]['Military Profile'])
original_cleaned = pd.DataFrame({
	"ID" : ids,
	"Clinical Profile" : clin_prof,
	"Military Profile" : military_prof
})

# %%
new_cleaned = new_cleaned.sort_values(by=['ID'])
original_cleaned = original_cleaned.sort_values(by=['ID'])

# %%
for new, old in zip(new_cleaned.iterrows(), original_cleaned.iterrows()):
	if new[1]['ID'] != old[1]['ID']:
		print(f"Difference: {new[1]['ID']} and {old[1]['ID']}")

# %%
count, total = 0, 0
for new, old in zip(new_cleaned.iterrows(), original_cleaned.iterrows()):
	new_index, new_row = new
	old_index, old_row = old
	total += 1
	if new_row['Military Profile'] != old_row['Military Profile']:
		print(f"ID = {old_row['ID']} | Old = {old_row['Military Profile']} | New = {new_row['Military Profile']}")
		count += 1
print(f"Done. {count}/{total}")
# Out:
# ID = 1006 | Old = NH | New = H1
# ID = 1011 | Old = H1 | New = H2
# ID = 1030 | Old = NH | New = H1
# ID = 1045 | Old = H1 | New = H2
# ID = 1050 | Old = H2 | New = H3
# ID = 1052 | Old = H1 | New = H2
# ID = 1053 | Old = H2 | New = H3
# ID = 1054 | Old = H1 | New = H2
# ID = 1060 | Old = NH | New = H2
# ID = 1071 | Old = NH | New = H1
# ID = 1074 | Old = NH | New = H1
# ID = 1075 | Old = NH | New = H2
# ID = 1083 | Old = NH | New = H1
# ID = 1088 | Old = NH | New = H1
# ID = 1090 | Old = NH | New = H1
# ID = 1099 | Old = H1 | New = H2
# ID = 1106 | Old = H2 | New = H3
# ID = 1116 | Old = NH | New = H2
# ID = 1119 | Old = NH | New = H1
# ID = 1121 | Old = H2 | New = H3
# ID = 1145 | Old = H1 | New = H2
# ID = 1151 | Old = H1 | New = H2
# ID = 1155 | Old = NH | New = H1
# ID = 1159 | Old = H1 | New = H2
# ID = 1165 | Old = H1 | New = H2
# ID = 1169 | Old = H1 | New = H2
# ID = 1172 | Old = H1 | New = H3
# ID = 1203 | Old = NH | New = H2
# ID = 1220 | Old = NH | New = H1
# ID = 1228 | Old = H1 | New = H3
# ID = 2055 | Old = NH | New = H1
# ID = 2060 | Old = H1 | New = H2
# ID = 2099 | Old = H1 | New = H3
# ID = 2113 | Old = H1 | New = H2
# ID = 2145 | Old = H1 | New = H2
# ID = 2164 | Old = H1 | New = H3
# ID = 2205 | Old = H1 | New = H2
# ID = 3019 | Old = NH | New = H1
# ID = 3060 | Old = H1 | New = H2
# ID = 3094 | Old = NH | New = H1
# Done. 40/203

# %%
for new, old in zip(new_cleaned.iterrows(), original_cleaned.iterrows()):
	if new[1]['Clinical Profile'] != old[1]['Clinical Profile']:
		print(f"Difference detected: {new[1]['ID']} and {old[1]['ID']}")
		break
print("Done")
# Out:
# Done

# %% [markdown]
# Conclusion: They are the same.
